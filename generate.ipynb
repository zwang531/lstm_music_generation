# %%
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

#check whether gpu is available
use_gpu=torch.cuda.is_available()

# read file
f = open('input.txt')
result = list()
result.append(f.read())
#for line in f.readlines():    
    #print(line)
    #line = line.strip()                
 #   result.append(line)              
#print(len(result))
#indices_start=[i for i in range(len(result)) if result[i].strip()=='<start>']
#num_tune=len(indices_start)
#tune=list()

#for i in range(len(result)-1):
#    tune.append(''.join(result[indices_start[i]:indices_start[i+1]]))
#tune.append(''.join(result[indices_start[-1]:-1]))

training_data = []
training_targets = []
test_data = []
test_targets = []
sentencelen = 25
for i in range(len(result)):
    #leave one more for validation set
    num_character=len(result[i])
    #k = num_character%sentencelen
    k = num_character//sentencelen
    for j in range(k):
        training_data.append(result[i][j*sentencelen:(j+1)*sentencelen])
        piece = result[i][j*sentencelen+1:(j+1)*sentencelen+1]
        if(len(piece)<sentencelen):
            piece = piece+" "*(sentencelen-len(piece))
        training_targets.append(piece)
    end = ""
    end1 = ""
    if(k*sentencelen<num_character):
        end = result[i][k*sentencelen:len(result[i])]
        if(k*sentencelen+1<num_character):
            end1 = result[i][k*sentencelen+1:len(result[i])]
            end1 = end1+ ' ' * (sentencelen - len(end1))
        else:
            end1 = ' '* sentencelen
        end = end + ' '* (sentencelen - len(end))
        end1 = end1+ ' ' * (sentencelen - len(end1))
        training_data.append(end)
        training_targets.append(end1)
        #print('0'* sentencelen)
k = int(len(training_data)*0.8)
test_data=training_data[k:]
test_targets=training_targets[k:]
training_data=training_data[:k]
training_targets=training_targets[:k]
#word to index
word_to_ix = {}
ix_to_word = {}
for sent in training_data:
    for characters in sent:
        if characters not in word_to_ix:
            word_to_ix[characters] = len(word_to_ix) 
            ix_to_word[len(word_to_ix)-1] = characters

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    idxs = torch.LongTensor(idxs)
    #print(len(tensor))
    #tensor = tensor.view(batch_size,len(tensor)/batch_size)
    return autograd.Variable(idxs)
def one_hot(ids, depth):
    """
    ids: Variable
    out_tensor:FloatTensor shape:[sentencelen, depth]
    """
    out_tensor=torch.Tensor(len(ids),depth)
    #if not isinstance(ids, (list, np.ndarray)):
     #   raise ValueError("ids must be 1-D list or array")
    ids = torch.LongTensor(ids.data.cpu().numpy()).view(-1,1)
    out_tensor.zero_()
    out_tensor.scatter_(dim=1, index=ids,value=1. )
    if torch.cuda.is_available():
        out_tensor=out_tensor.cuda()
    return autograd.Variable(out_tensor)

# %%
EMBEDDING_DIM = len(word_to_ix)
HIDDEN_DIM = 100

class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)
        self.hidden = self.init_hidden()

    def init_hidden(self):
        # Before we've done anything, we dont have any hidden state.
        # Refer to the Pytorch documentation to see exactly
        # why they have this dimensionality.
        # The axes semantics are (num_layers, minibatch_size, hidden_dim)
        return (autograd.Variable(torch.zeros(1, 1, self.hidden_dim).cuda()),
                autograd.Variable(torch.zeros(1, 1, self.hidden_dim).cuda()))

    def forward(self, sentence , hidden):
        #print(sentence)
        #embeds = self.word_embeddings(sentence)
        embeds=one_hot(sentence,EMBEDDING_DIM)
        lstm_out, hidden = self.lstm(
            embeds.view(len(sentence),1,-1), hidden)
        #print(self.hidden)
        tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
        #tag_scores = F.softmax(tag_space)
        return tag_space,hidden
    


model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix), len(word_to_ix))
model.load_state_dict(torch.load('mytraining.pth'))
loss_function = nn.CrossEntropyLoss()
if use_gpu:
    model.cuda()
    loss_function.cuda()
optimizer = optim.SGD(model.parameters(), lr=0.1)
#inputs = prepare_sequence(training_data, word_to_ix)
error_train = []
error_valid = []
loss_f = 0
k = 0
epoch = 0

# %%
def evaluate(prime_str="<start>", predict_len=10000, temperature=1):
    hidden = model.init_hidden()
    prime_input = prepare_sequence(prime_str, word_to_ix)
    predicted = prime_str
    model(prime_input,hidden)
    for p in range(len(prime_str) - 1):
        _, hidden = model(prime_input[p], hidden)
    inp = prime_input[-1]
    for p in range(predict_len):
        model.lstm.flatten_parameters()
        output, hidden = model(inp, hidden)
        # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        # Add predicted character to string and use as next input
        predicted_char = ix_to_word[top_i]
        predicted += predicted_char
        inp = prepare_sequence(predicted_char, word_to_ix)
        end = predicted[len(predicted)-len("<end>"):]
        #if(end == "<end>"):
         #   break
    print(predicted)
    return predicted

res = evaluate()
# Out:
# <start>
# X:72
# T:Mish Mais Jig, The
# R:jig
# H:See also #7, Dopipe-86
# M:7/4
# L:1/8
# K:D
# DEFD
# agbc' a g2:|
# <end>
# <start>
# X:29
# T:Mazurke to ta|gfge dBGd|BAGE BGFA|(3Bcd ed ef/g/a/g/|
# gf ggfe|degf geed|fdc d2e:|2 gg fedf edb2 Bedg|fbaf ggfg|a
# Z:id:hn-reel-20
# <start>
# X:73
# T:Jading Heateros.
# Z:id:hn-reel- MecMorctocklo's 19k>a-ve
# H:See glet andyna & ce e2 (3BAF|(3/eg-f/e/d/A/|1 Gged c2e2|elk toeter GCeol is and Mereet
# H: ceumazolke's Nestdget Brolka-825
# M:C|
# <end>
# <start>
# X: 1
# T:Mary Berge. |
# <end>
# <start>
# X:58
# V:2
# GE EE G>E DG Bd MAB/A/B/AB|1 Gg ag|ef~g2 a2ce:|
# <end>
# <start>
# X:9
# T:Mickn
# Tosby
# T:Hureed: f The
# R:reel
# D:Seanhe gfeg|| f2b>a gfg|adcd cAFA|GGef ge~g2|e2 dedd|| e2aged gadf |
# f2b2 gbed cAFE EDGF|~F3 DFAE|BG GB|cB BA|DEFA GBAG|AEFA|AAA=c=BAGA|cFA ~D3|FAB cAF|GGBd BdBg|egga gege|d2:| e4- e'ec:hn-porng Up Paoy, The
# T:bleyn: aldorddy
# R:jig
# H:Gila (edcB|
# c4 fe|gaig apol/2gad AGFE|:d2ec cAGA||
# <end>
# <start>
# X:45
# T:Stolleu boo Choud the Longor" Cieellonsto"
# C:Jongerun Turreegle's Wangad Rumboerick Polka-carrations
# |:G2Bd "Cmaedcharan Chabew pielle
# O:France
# A:Provence
# C:Trad.
# Z:id:hn-reel-17
# M:C|
# K:G
# ~G3B G2FG|dGBd ga~ag|aged ceef|edef|g2ed eede|ca b2|ed^c2 d2ee|fede cBdfg|dedA cAFA|BADEGE|~AGFE EEFA|BAGEDE AFE|A3FDE|DFG BAE|D2DG ~E2GF|A2AB A2 (3ged|gfgf edcB|A2A2 BABd:|herve -ges one of Marchects"G2|
# w:Torrige Kengerad ato
# BGGE E2~E3|d>e (3f ef ed:|2 d3-f/e/d/e/|d/f/4 g2|D/e/f/g/|dB Bd|ed Bd|df/e/dBG B/A/F/G/E/|~E2GE EDEF|
# ~A3c AcBA|GAcB A2ba|aed dBG|AFAc f/AB|1 BAAG EFAd|gba eege|dGE GBd:: fidlade
# H:pese|dfed cAGE|FAAB c2de|fdef egfe|(3Bcd Bd ceef|def gea|~g2abyerspie, The
# R:Twomon C | ABdA AdDF | EDEF GGBd | eg~g2 bgea | a2fe dcBA | cdefeg ag|dB~B2 edefge|eagd cAFA|
# BGGG EGAB|cAGABGAd.el -1200-1731)
# Z:id:hn-polka-38
# M:2/4
# L:1/8
# K:D
# D>D FADF|AGB2 BAED|DB~B2 cA~A3|BE~E2 EDef|e^B dG|FDDF AGEF|GEGB Bcde|edBfe d2df|efed gdeB:|2 gg/d/ ef|ef/e/ dB|cAG>A|Gg~g2 bg~g2|fBBd edfa afge|afb' gfge|dB~A2 eBdB|A2Ad fege|d^cdhef B2BA|A2cB A2 (3efg|abe2 ageg|dcA A2F|d2Bd e2A2|B2A2 EGED|A/A/G/F/G|EG/A/cBA|~G3A BAcd|ed eded|ggfg|edB A2:|
# <end>
# <start>
# X:98
# L:1/8
# K:Amix
# GGAB cAd~g2|edgfgaf|(fed edB|
# A8AB | AGFe dBAF | BAGFABd | e>ffg ~g3ag|1 edB d2B2 BAFA|1BA GE|e^d/e/ d2d/c/|BA EG|A2 FAFG|EGAF G2EF|GFGB|FAAG EGAG|FG~G2 dGAB|cAFA DGAG|EGAB cGAF||
# ~G2 GBAG|AGFE FAFD|GFGDEF|EGEG dfe^dcB AGDE|DBAF GEFA|
# dg~a2 bgef|eaag aged|eedcB^A | AGED AGBd::deg gb|da/g/ dfdd|efgf gedd:|
# |:dBAG~E2ED|ggefge|fedB ceBA|BAGB A2ff|~g3g eABc|dddg fd/e/|dBEdAG|[AA^FA ^FdBA|GE~D2 bged|cBAA f2dc|d2f4
# <end>
# <start>
# X:77
# T:Gf|gB~g2 dA~g3 feg|afan#3
# D:Mayy Magreey Pheedhare and Alande
# H:S\'w therc nnome
# H:See also #12
# Z:id:hn-reel-5
# M:C|
# K:4
# Q:1/8
# K:Dminegel Bnd Ke
# E2 ce dcd|1 AGGF GBdg||
# ad dB|BE geec dega|bg~ag fgag|agaa ge~D2 ~E3D:Clho Ledgeledduf ceeA|edAGAB|
# BA~A2FAB AFAB|cAG2 ^G2gf|aged cBAG|ADAc AGA | cAA ~G3d |
# e3 ecA | eAGABcd efge|dfaf gefg|1d3 ege|defd efee|edBG|geae eged|cAAB d2ff|gagf gedB DFAAc|
# f3|fed eAG|
# M:2 D2:carbeson
# M:6/8
# L:1/8
# K:Dmix
# C:TradcEA BBAB|G2EA BE~D2D2 BBAB||
# P:Verscleer, The
# R:jig
# C:Hewg.fre.chinginagh, The
# R:polka
# H:Versing 2 Befed edef|gege bgeg|1 e2de degf|gfed cAFD|
# |:fe eg|eA AG|EF GEFA|B,GFG ABcd|eGEDED||
# <end>
# <start>
# X:98
# T:Mazurka.o Sndigi, G,EG|
# B3D GABc|defd cAD2|G2E2 EEFE|~G3ABG|EABc dAGD |
# BcdB AGEF||
# P:Versiongy Waghtte manced Bengiler
# M:2/4
# L:1/8
# K:Dm
# BA Bc||
# |:ac/a/bg/f/|1 e2 egg?:ef e/f/g/hf/) ga|gfge dBGB|A3F AGAB|c^F AG|BABA DEFA|dBGB dAFA|GBdB BcdB|dcAA DEFA|1 AGDFEF FGA^c|dBGAB BEc dcB Af|ED E2:|
# |:Davation
# R:cd g2|efgf aged|
# f/f/g/f/e/d/ dd|B4:|
# <end>
# <start>
# X: 69
# T:Timey Pecortine
# T:Frool
# Dg e/f/e/e/|fe~e2 edBd|
# cdef gedB|1 B2AB GABd|eA~A2 =GABa|~g3a bgba|gf~g2 bged|egef EFGE|EABG GCa2g|fef e2d|=c6:
# R:jig
# H:See adstadf
# R:polka
# H:GBEFGA |
# Aa/b/a/g/ ge/d/(c/B/A/ B  | BB BG | GGFED2 | F2D2 DEFA | G2 GA |
# BB BE EDD2|AGFEFg|fede ^AAAFAd.d.
# Z:id:hn-ree
# H:Aarolan's
# R:mazurka
# D:Matt Molkanty Faree Mefe,  AcAG A^Ggg|eag ged|f2dB AGFG|e2) ed|cA AB|c>d cA|gf/g/bagfe|
# ~G2B3G AccB|c2AF GEFE|
# FGAB AGBA|eege dBG2|gedG cfeG|FADE AFEF|~G3A Fddc|BA~G2 BG^FG|^GA=GBG BGBGdB ~A3G AGFA EGgf |~g3a gedB|cGBAGA|BAGA BG~E2|~E3DEF|E2EAG GED2:|
# <end>
# <start>
# X:8. Glackree
# AGB>d fecd|pee.fr
# M:6/8
# G2GBG A4|
# P:Variations
# |:
# dGFG ABGB|d2 B2 BGgalle
# D:Mazurka
# R:reel
# A:Rete By: Azurka
# Z:id:hn-reel-12
# M:2/2 ka bg DE FD G4|GABc dcdB|cdef gefg|afa afd|ede cdc|dBGB B4|BG~G2 EGE2|FE D2||
# <end>
# <start>
# X:9
# T:Neallad a S||
# |:cA|Af ge/e/||
# ed ef|ebed eged|e2dB AGFE|D2DF FAGE|c2A eAG|AFGA ABcd|edcB AG2G|BDEF BEGB||
# <end>
# <start>
# X:23
# T:Tlewend vie 3Adfe|dcef efee|daad a ac:hn-reel-16
# M:C|
# L:1/8
# K:Ddel-27
# M:C|
# K:Ddor
# BA GB/A/|BE~E2|FGAF GEEG||
# |:~g3feefe | f3- | dcBA GCZ2 | D2FGEF G2Ac|BAGF GBcd|edBd|~g3d geef|89
# M:2/4
# L:1/4
# K:F
# A>BA ~A3B|cBAGEGABAGB
# X:99
# T:Thef Boysose
# H:See also #14 |
# |:d2 aded|(3efe d2BB|defg a2fg|a3 bgfe|dg~g2 efge|dBGF GBdB|d4:|
# <end>
# <start>
# X:7
# T:Jeamer doullo BnamB cage=cA GEDG|~D2EA DEAB|GABc BGAB|c3d efed|eged|eAFABA|G2GF GEDA||
# DBG~G3B BEBE|AEFE cBcd|eedB gBed |
# efed edBG | GBG BGE | Bcfg |A2~G2 BGAB|
# afbg age/f/ed|B2 B>B|AG/C/ ABGB|AGBd BgdB|A2G(3efg fedc|BAGF GFGA||
# P:VerscH:Frrig agfge dcA(3B^cB|dB Bdce|fdge dAGE|EA GAGG|FAde fgeg|fagf AAFD|
# FAA| EAEDFAF |1 ABAc A2BA | Bdga g3fe || e2dB AFD2 | A>dcd cAFA||
# BAGE EEDF||
# P:Variations EF|1 GE/G/B/G/|fd ce|ge/f/eA edH:Alandogar's ato
# B^cde a2dB|BABB | cFA|c2Ac gBf+aged d2de|f2g2 gedB|~B3d dcAG|~G3F GEFD|
# G2 FE|E2 EFGE|FDFA B2de fgae|ddGB G3ABG:|2 G2:|2 B4 GG :|2 BAGEGF GABG|cABc BBAB | B A2 Bd g4 d/cB | ef ef gd cA | BD GB/d/ ef ||
# <end>
# <start>
# X:58
# T:Neil the I Keale way Reree's birgal addede geAG|AFAG A2Bc|dBAG ABAG|
# BDDE AGEG|AGEE EFAA|BE~E2 EEFE|
# G(edeagfege|dgfg edcB|ABAGABA|1 GEEGEFGEDAB2 : (3efg a2ge |
# af|eG~A2 BA~G32 A2~G2|AGFE DEFE|FAdd efge|feagefdeg (3efg also pleys.
# <end>
# <start>
# X:98
# T:O'Re Holland O'Michang upste
# R:re2 ABAG AGB^c | d2ge dfefdg | fed cAA | Bdf geAB | c2d2 d2dB | G2F2B4 g3f|ea~a2 bgag|cecd Edfd|ABAF EFAG|
# AGAB cBcd|eB~end>
# <start>
# X: 87
# T:Vermoy
# T:AAB BABd | c3A ABcA:|2 ce eBcB | AGAG FE D2 :|
# <end>
# <start>
# X:91
# T:Pafly Loel cc|dd B/c/d|e2 g>f ec|dB cAFG|AG EA~B2 |
# A3f gefa || a2g fddd |
# a2~g2 Be~f3e fedB |
# d2c GBd|BAGF E4:|
# <end>
# <start>
# X:69
# T:Bluvel Michel BELLON - GEFG|1cAAd BA.A.G |:
# K:Ddor
# end>
# <start>
# X:12
# T:Acland Corgest
# R:Barghtorn Brochas.
# Z:id:hn-reel-1/d/ Bgfg|abag a2b|
# agfe dcBA|(3EDe Canter" |
# Bcdf agfehe
# R:reel
# D:Whefre4 e2|ce ed|ebaf ged2|Bcde dged|eggf~g2|eAcege|gfed BGAF|GEED 1897 thngtorunpondy, The
# R:Hot~g aged:hn-reche Islambour, Reg
# R:polka
# H:Gagge | fdd d2A:|2 ededB2|A2B2 e2|d2gf ggae|e!bsey.
# W:Oweanecoredd efed:|2 ded efga|baag edgc|The
# R:mazurka
# D:Misse hishise
# D:Devin Twoeraisso oneche Kenne
# C:Merichure.fror'D Michallefr
# R:reel
# D:John Mc<tars allenn'
# BGBdBdBc degge2gabarohe fine : Hor uanerrielle, slagel
# R:mazurka
# H:"Smeand>
# <stain Budef The
# T:Cusher and to Ther McActer cBA cA evered BAcdcB (3efg efeA|: EDE2ed B<AA|gedB G198045-04-17-239)
# Z:id:hn-reel-3
# M:2/4
# L:1/8
# K:Dm
# aDEFA|d2d2:|2 dBAG E4c ||
# <end>
# <start>
# X:27
# T:Reol Five Polky:Che The
# C:Prady's
# R:polka
# H:Thiefrains
# Z:id:hn-reel-39
# M:C|
# K:Dmix
# D:Johney
# T:John Def|g2gb aged|fadA cA~Af|~g3d efge|edcd ega2|~g3e BAcB|fAA B>B|AFED G2GG|(3ccA AGEF|G2 B2 BA(Ep:weld de Lant in AGFA|dddB | cA AB/c/ |
# AA^F G>ABGA Bd|e2ga gedA|dgag ged2|
# Bd B2 FG|A2 ce.e | bgag agge | ddde fgfe | A2ef gege | g4edBc dGAB | AGF EDF|(3DcB BAFG|e2 eded gedB|cBAA BBAG|(3EDD: Bbreel ecolde
# Z:id:hn-reel-5
# M:2/4
# L:1/8
# K:Emig
# D:Fryito Clamor
# T:Musttys Michave
# D:Challacky
# T:Breat>
# X:9
# T:Sowge^fe gedB|c2A2 E2DE|1 GBE EBcd:|
# |:ge ed|gd cBm7-41
# M:6/8
# L:1/8
# K:G
# GBAB ABcd eded|c2 BA BB|AB BG/B/B:Ther Begboundy 2listarf)
# D:Matt Michallone at Magann:
# Hridhe lowet
# R:Danse owellingste colland <tart>
# X:98
# T:Fionnyle
# R:barndan Polka, The
# R:reel
# D:Chorme wither ddcB|Ad geed|ea/g/ de|feafef ge^ce|fagf efag|adab|g2ge dBcd|e2af edBA||
# |:ea ag|a4 ba a|fne, Tuec::fndele
# H:Or2de|d2F2
# D2EF A4d2 | dG~G2 BGGA BGE3|BAF|~B3/G/GA|BAGF GEDE|FGAB BEAG|AGEF E2DF:|2 G2GG E4DG | ABAG AGE2:|
# <end>
# <start>
# X:23
# T:Mazurka
# R:polka
# D:Deatervars!G,2 BD GABd|g2dB ~G3c|BGEG ABef|de gefg|aagadB EGEF|DEFG A2FA|BdBE ~E3EFE|DGBd Bded|cAde gdBc|dcA fef|1 gecd cBA2 |
# GBdB GDBG | ABFA A3Bc|"Gmabg gadd|agef afed|1 cBAG EAc|(3efe (3Bed|egedBA|GFAG DGA_ecAAF|G2AB G3A AGFE|D2FA BABG|AGFG GED2|ce cege|fAG AFE|D2DC DcFA|GAFEFE fedB|BAcB cdef|gfge ddgA|fB|cAc ge^c||
# |:agfe g2fe|dfed dBAB|cABc dyoga/ Bd|e2 E>EG|cBAG EGAE|BGEDEGF|EEFA EDDF|
# AdBdeg dcBA|FABc e2A2 e>d:|
# <end>
# <start>
# X:21
# T:Chaty of "<eally Darney.ess
# gfgf bged|ed efed|cdee fdcB|ABAG EDAF|1 GEEG Ad|fdcA C1954parts - Vicldent>
# X:9
# T:Ally Restpea Ther.
# Z:id:hn-polka-12
# M:2/4
# L:1/8
# K:Dmix
# AG~E2 EEAB|A^FAd gBAG|AFde edcA|Abag dfge|d2A2BA|DFDE BA~E2|A2 DEF|1 AGEE EGcA2|B2B2 AGDG|
# ~G3B ~G3^FAG:|2 GEE E>G2~G2
# X:48
# T:Onde2|Bcde fged dAGE||
# B2 cdef g2fg|efgf gedB|BAFG|dBdf|e2e=Bcd | g2fd mitines Blackie figel-21 eadb ab c'ba ||
# P:Variations:
# |:A,EE ^FE/A/=A/G/F/G/|AB B2|B3/2F/ | FG GBcd | ef/e/ dc GA Bd||
# |:D3/F/A/f/ gedd|d2 fg|fdgf g215185
# Z:id:hn-reel-13
# M:C|
# K:G
# GA~G2 eAA^ce|1 eaag aged|edegef|bagb agdg|fdd ~c3|BGBB GBcB|1 BG~G2 AGGB|~f2dB BABF|AABc d3e:|2 dBd e3g||
# <end>
# <start>
# X:75
# T:Jarian Reau
# R:jig
# C:Es.D2D/2A,|
# 3AB c4|AG~F2 d2cd|efgf efAB|Bgeg (3agf =Bwer.
# H:See pleyswar, The
# R:jig
# D:Movinggane ie Rick, The
# R:polka
# D:Mary
# H:ind Shede #42007-0
# 3:Rilso on play
# C:John Beewe ffecde|cAAB A2cA|d2gf gedB | ABcd ecBd |
# c6ABc | AcBG fdcBBd :|
# |: cde fgag edBd c2AB|cAAc cAGF|dfgf efge|1fed A2e: afaa 5983\
# BED|FEDD |
# S:CEF|GCE DEF|EDFA BAAF|GGE|ABAG GABG|BG~G2 BAcB|AFAc BAFD|FEFAF2:Aloved<eregle's Muteronarn
# D:S. Jondy PafdB|BdBB e2dB|G2 Bd|A^F AF:Charen Heansy observationgmana21/8
# K:Ador
# dd|B2 B>A| d2gag^fad (3efg af edBG|~A3A AGED ~G3 :|2 BGF:|2 B2E2 GDcA BAcB |
# A2 c2
